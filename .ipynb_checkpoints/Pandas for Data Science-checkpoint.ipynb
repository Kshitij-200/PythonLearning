# %%
import pandas as pd

# %% [markdown]
# # Create

# %% [markdown]
# ## Create from a CSV

# %%
df = pd.read_csv("Tesla Deaths.csv")

# %% [markdown]
# # Create from a Dictionary

# %%
tempdict = {
    "col1":[1,2,3],
    "col2":[4,5,6],
    "col3":[7,8,9]
}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# # Read

# %% [markdown]
# # Show top 5 and bottom 5 rows

# %%
df.head(10)
# Out:
#    Case #  Year       Date   Country   State   \
# 0     254  2022  8/16/2022   Germany      NaN
# 1     253  2022  8/15/2022       USA       CA
# 2     252  2022  8/14/2022   Finland      NaN
# 3     251  2022   8/2/2022       USA       FL
# 4     250  2022  7/27/2022       USA       ME
# 5     249  2022  7/24/2022       USA       UT
# 6     248  2022  7/16/2022       USA       PA
# 7     247  2022  7/12/2022     China      NaN
# 8     246  2022   7/8/2022       USA       CA
# 9     245  2022   7/8/2022       USA       HA
#
#                               Description    Deaths   Tesla driver   \
# 0      Tesla car crashes into tree, burns          2            NaN
# 1       Tesla veers into oncoming traffic          4              1
# 2       Unlicensed driver hits pedestrian          1             -
# 3     Man in wheelchair hit crossing road          1             -
# 4             Tesla crashes at high speed          1              1
# ...

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.tail(15)
# Out:
#      Case #  Year        Date  Country   State   \
# 239      15  2016    5/7/2016      USA      FL
# 240      14  2016   4/22/2016      USA      CA
# 241      13  2016    4/8/2016      USA      OH
# 242      12  2016   1/20/2016    China      NaN
# 243      11  2015  12/28/2015      USA      TX
# 244      10  2015  12/22/2015   Canada      NaN
# 245       9  2015  11/18/2015      USA      CA
# 246       8  2015   6/22/2015      USA      CA
# 247       7  2015   1/22/2015      USA      CA
# 248       6  2014  12/30/2014      USA      CA
# 249       5  2014   7/14/2014      USA      CA
# 250       4  2014    7/4/2014      USA      CA
# 251       3  2014    7/4/2014      USA      CA
# 252       2  2013   11/2/2013      USA      CA
# 253       1  2013    4/2/2013      USA      CA
#
#                                    Description    Deaths   Tesla driver   \
# 239                  Autopilot into 18 wheeler          1              1
# ...

# %% [markdown]
# # Show Columns and Data Type

# %%
df.columns
# Out:
# Index(['Case #', 'Year', 'Date', ' Country ', ' State ', ' Description ',
#        ' Deaths ', ' Tesla driver ', ' Tesla occupant ', ' Other vehicle ',
#        ' Cyclists/ Peds ', ' TSLA+cycl / peds ', ' Model ',
#        ' AutoPilot claimed ', ' Verified Tesla Autopilot Death ', ' Source ',
#        ' Note ', ' Deceased 1 ', ' Deceased 2 ', ' Deceased 3 ',
#        ' Deceased 4 '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Case #                                int64
# Year                                  int64
# Date                                 object
#  Country                             object
#  State                               object
#  Description                         object
#  Deaths                               int64
#  Tesla driver                        object
#  Tesla occupant                      object
#  Other vehicle                       object
#  Cyclists/ Peds                      object
#  TSLA+cycl / peds                    object
#  Model                               object
#  AutoPilot claimed                   object
#  Verified Tesla Autopilot Death      object
#  Source                              object
#  Note                                object
#  Deceased 1                          object
#  Deceased 2                          object
#  Deceased 3                          object
#  Deceased 4                         float64
# dtype: object

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#           Case #         Year     Deaths    Deceased 4
# count  254.00000   254.000000  254.000000           0.0
# mean   127.50000  2019.732283    1.196850           NaN
# std     73.46768     2.073544    0.495663           NaN
# min      1.00000  2013.000000    1.000000           NaN
# 25%     64.25000  2019.000000    1.000000           NaN
# 50%    127.50000  2020.000000    1.000000           NaN
# 75%    190.75000  2021.000000    1.000000           NaN
# max    254.00000  2022.000000    4.000000           NaN

# %%
df.describe(include = "object")
# Out:
#              Date  Country   State               Description   Tesla driver   \
# count         254       254     185                       254            250
# unique        230        22      34                       212              2
# top     5/28/2022      USA      CA    Tesla kills pedestrian              -
# freq            3       185      75                        10            151
#
#         Tesla occupant   Other vehicle   Cyclists/ Peds   TSLA+cycl / peds   \
# count               246             251              252                253
# unique                4               5                3                  5
# top                  -               -                -                   1
# freq                210             154              215                137
#
#         Model   AutoPilot claimed   Verified Tesla Autopilot Death   \
# count      251                 250                              254
# ...

# %% [markdown]
# # Filtering Columns

# %%
df.Date
# Out:
# 0      8/16/2022
# 1      8/15/2022
# 2      8/14/2022
# 3       8/2/2022
# 4      7/27/2022
#          ...
# 249    7/14/2014
# 250     7/4/2014
# 251     7/4/2014
# 252    11/2/2013
# 253     4/2/2013
# Name: Date, Length: 254, dtype: object

# %%
df.Date.unique()
# Out:
# array(['8/16/2022', '8/15/2022', '8/14/2022', '8/2/2022', '7/27/2022',
#        '7/24/2022', '7/16/2022', '7/12/2022', '7/8/2022', '7/7/2022',
#        '7/6/2022', '7/5/2022', '6/26/2022', '6/20/2022', '6/17/2022',
#        '6/14/2022', '6/13/2022', '6/7/2022', '6/3/2022', '5/28/2022',
#        '5/25/2022', '5/23/2022', '5/21/2022', '5/19/2022', '5/18/2022',
#        '5/16/2022', '5/12/2022', '5/11/2022', '5/7/2022', '5/1/2022',
#        '4/29/2022', '4/10/2022', '4/8/2022', '3/26/2022', '3/21/2022',
#        '3/20/2022', '3/14/2022', '3/13/2022', '3/12/2022', '3/7/2022',
#        '3/5/2022', '2/28/2022', '2/27/2022', '2/12/2022', '2/7/2022',
#        '1/16/2022', '1/1/2022', '12/31/2021', '12/28/2021', '12/24/2021',
#        '12/18/2021', '12/11/2021', '12/7/2021', '12/2/2021', '12/1/2021',
#        '11/29/2021', '11/15/2021', '11/8/2021', '11/6/2021', '11/4/2021',
#        '10/28/2021', '10/15/2021', '9/17/2021', '9/13/2021', '9/4/2021',
# ...

# %% [markdown]
# # Filtering the rows

# %%
df.head()
# Out:
#    Case #  Year       Date   Country   State   \
# 0     254  2022  8/16/2022   Germany      NaN
# 1     253  2022  8/15/2022       USA       CA
# 2     252  2022  8/14/2022   Finland      NaN
# 3     251  2022   8/2/2022       USA       FL
# 4     250  2022  7/27/2022       USA       ME
#
#                             Description    Deaths   Tesla driver   \
# 0    Tesla car crashes into tree, burns          2            NaN
# 1     Tesla veers into oncoming traffic          4              1
# 2     Unlicensed driver hits pedestrian          1             -
# 3   Man in wheelchair hit crossing road          1             -
# 4           Tesla crashes at high speed          1              1
#
#    Tesla occupant   Other vehicle   ...  TSLA+cycl / peds   Model   \
# 0              NaN              -   ...                  2     NaN
# 1                3              -   ...                  4     NaN
# 2               -               -   ...                  1     NaN
# ...

# %%
df[df["Year"] == "No"]
# Out:
# Empty DataFrame
# Columns: [Case #, Year, Date,  Country ,  State ,  Description ,  Deaths ,  Tesla driver ,  Tesla occupant ,  Other vehicle ,  Cyclists/ Peds ,  TSLA+cycl / peds ,  Model ,  AutoPilot claimed ,  Verified Tesla Autopilot Death ,  Source ,  Note ,  Deceased 1 ,  Deceased 2 ,  Deceased 3 ,  Deceased 4 ]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[(df["Year"] == "No") & (df["Deaths"] == False)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Deaths'
#
# ...

# %% [markdown]
# # Indexing with iloc

# %% [markdown]
# # Indexing with iloc
